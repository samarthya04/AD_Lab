# %% [markdown]
# <a href="https://colab.research.google.com/github/samarthya04/AD_Lab/blob/main/LabEvaluationProblem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
data = {
    'Experience': [5, 10, 2, 1, 23, 8],
    'Feedback':[5, 5, 3, 0, 1, 2],
    'Promotion': ['Yes', 'Yes', 'No', 'No', 'Yes', 'No']
}

# %%
df = pd.DataFrame(data)
df.head(6)
# Out:
#    Experience  Feedback Promotion
# 0           5         5       Yes
# 1          10         5       Yes
# 2           2         3        No
# 3           1         0        No
# 4          23         1       Yes
# 5           8         2        No

# %%
X = df.iloc[:, :-1]
y = df['Promotion']

# %%
clf = KNeighborsClassifier(n_neighbors=3)
clf.fit(X, y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
prediction = clf.predict(np.array([[12, 3]]))
print(f'Prediction Status: {prediction[0]}')
# Out:
# Prediction Status: Yes
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
